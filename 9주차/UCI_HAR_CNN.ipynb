# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaia-nyoung/2025-ML-class/blob/main/9%EC%A3%BC%EC%B0%A8/UCI_HAR_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
def load_file(filepath):
    data = np.loadtxt(filepath)
    return data

# %%
def load_group(filenames, prefix=''):
    loaded = []
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    loaded = np.dstack(loaded)  # (샘플 수, 타임스텝, feature 수)
    return loaded

# %%
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    filenames = [
        'body_acc_x_'  + group + '.txt',
        'body_acc_y_'  + group + '.txt',
        'body_acc_z_'  + group + '.txt',
        'body_gyro_x_' + group + '.txt',
        'body_gyro_y_' + group + '.txt',
        'body_gyro_z_' + group + '.txt',
        'total_acc_x_' + group + '.txt',
        'total_acc_y_' + group + '.txt',
        'total_acc_z_' + group + '.txt'
    ]
    X = load_group(filenames, filepath)
    y = load_file(prefix + group + '/y_' + group + '.txt')
    return X, y

# %%
def load_dataset(dataset_root='/content/drive/MyDrive/ML-MK/UCI_HAR/'):
    trainX, trainy = load_dataset_group('train', dataset_root)
    testX,  testy  = load_dataset_group('test',  dataset_root)

    # 라벨이 1~6 → 0~5로 맞추고 원핫
    trainy_one_hot = to_categorical(trainy - 1)
    testy_one_hot  = to_categorical(testy - 1)
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# %%
trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()

X_train, X_val, y_train_one_hot, y_val_one_hot, y_train, y_val = train_test_split(
    trainX, trainy_one_hot, trainy,
    test_size=0.2,
    random_state=100
)

n_timesteps, n_features = X_train.shape[1], X_train.shape[2]
n_outputs = y_train_one_hot.shape[1]

print("✅ Data loaded successfully")
print("train:", X_train.shape, y_train_one_hot.shape)
print("val  :", X_val.shape,   y_val_one_hot.shape)
print("test :", testX.shape,   testy_one_hot.shape)
# Out:
# ✅ Data loaded successfully
# train: (5881, 128, 9) (5881, 6)
# val  : (1471, 128, 9) (1471, 6)
# test : (2947, 128, 9) (2947, 6)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout

# %%
def build_better_cnn():
    model = Sequential()
    model.add(Conv1D(64, 3, activation='relu', input_shape=(n_timesteps, n_features)))
    model.add(BatchNormalization())
    model.add(Conv1D(64, 3, activation='relu'))
    model.add(MaxPooling1D(2))
    model.add(Dropout(0.3))

    model.add(Conv1D(128, 3, activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv1D(128, 3, activation='relu'))
    model.add(MaxPooling1D(2))
    model.add(Dropout(0.3))

    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(n_outputs, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
cnn_model = build_cnn_model()
history_cnn = cnn_model.fit(
    X_train, y_train_one_hot,
    validation_data=(X_val, y_val_one_hot),
    epochs=50,
    batch_size=64,
    verbose=1
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.6405 - loss: 0.8858 - val_accuracy: 0.9048 - val_loss: 0.2918
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8999 - loss: 0.2586 - val_accuracy: 0.9225 - val_loss: 0.1883
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9509 - loss: 0.1296 - val_accuracy: 0.9232 - val_loss: 0.1603
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9563 - loss: 0.1146 - val_accuracy: 0.9409 - val_loss: 0.1461
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9605 - loss: 0.1069 - val_accuracy: 0.9409 - val_loss: 0.1389
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9509 - loss: 0.1243 - val_accuracy: 0.9504 - val_loss: 0.1204
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9580 - loss: 0.0994 - val_accuracy: 0.9341 - val_loss: 0.1339
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9545 - loss: 0.0965 - val_accuracy: 0.9429 - val_loss: 0.1273
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9582 - loss: 0.0962 - val_accuracy: 0.9483 - val_loss: 0.1089
# Epoch 10/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9584 - loss: 0.0920 - val_accuracy: 0.9531 - val_loss: 0.1075
# Epoch 11/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9599 - loss: 0.0950 - val_accuracy: 0.9531 - val_loss: 0.1068
# Epoch 12/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9599 - loss: 0.0836 - val_accuracy: 0.9565 - val_loss: 0.1003
# Epoch 13/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9628 - loss: 0.0872 - val_accuracy: 0.9524 - val_loss: 0.1013
# Epoch 14/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9646 - loss: 0.0834 - val_accuracy: 0.9415 - val_loss: 0.2191
# Epoch 15/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9596 - loss: 0.0982 - val_accuracy: 0.9483 - val_loss: 0.1150
# Epoch 16/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9552 - loss: 0.1015 - val_accuracy: 0.9565 - val_loss: 0.0949
# Epoch 17/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9686 - loss: 0.0723 - val_accuracy: 0.9565 - val_loss: 0.0914
# Epoch 18/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9639 - loss: 0.0726 - val_accuracy: 0.9674 - val_loss: 0.0721
# Epoch 19/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9666 - loss: 0.0726 - val_accuracy: 0.9613 - val_loss: 0.0798
# Epoch 20/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9713 - loss: 0.0621 - val_accuracy: 0.9626 - val_loss: 0.0768
# Epoch 21/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9676 - loss: 0.0619 - val_accuracy: 0.9714 - val_loss: 0.0732
# Epoch 22/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9729 - loss: 0.0606 - val_accuracy: 0.9653 - val_loss: 0.0744
# Epoch 23/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9708 - loss: 0.0596 - val_accuracy: 0.9721 - val_loss: 0.0660
# Epoch 24/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9759 - loss: 0.0555 - val_accuracy: 0.9579 - val_loss: 0.0767
# Epoch 25/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9736 - loss: 0.0508 - val_accuracy: 0.9592 - val_loss: 0.0765
# Epoch 26/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9771 - loss: 0.0511 - val_accuracy: 0.9579 - val_loss: 0.0778
# Epoch 27/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9752 - loss: 0.0545 - val_accuracy: 0.9769 - val_loss: 0.0646
# Epoch 28/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9788 - loss: 0.0456 - val_accuracy: 0.9599 - val_loss: 0.0759
# Epoch 29/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9797 - loss: 0.0447 - val_accuracy: 0.9708 - val_loss: 0.0689
# Epoch 30/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9779 - loss: 0.0420 - val_accuracy: 0.9708 - val_loss: 0.0726
# Epoch 31/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9734 - loss: 0.0578 - val_accuracy: 0.9599 - val_loss: 0.0996
# Epoch 32/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9694 - loss: 0.0736 - val_accuracy: 0.9640 - val_loss: 0.0681
# Epoch 33/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9776 - loss: 0.0491 - val_accuracy: 0.9742 - val_loss: 0.0641
# Epoch 34/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9778 - loss: 0.0465 - val_accuracy: 0.9742 - val_loss: 0.0624
# Epoch 35/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9780 - loss: 0.0434 - val_accuracy: 0.9748 - val_loss: 0.0636
# Epoch 36/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9780 - loss: 0.0465 - val_accuracy: 0.9735 - val_loss: 0.0660
# Epoch 37/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9772 - loss: 0.0499 - val_accuracy: 0.9667 - val_loss: 0.0834
# Epoch 38/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9756 - loss: 0.0512 - val_accuracy: 0.9680 - val_loss: 0.0698
# Epoch 39/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9664 - loss: 0.0842 - val_accuracy: 0.9613 - val_loss: 0.1255
# Epoch 40/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9735 - loss: 0.0867 - val_accuracy: 0.9714 - val_loss: 0.0679
# Epoch 41/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9832 - loss: 0.0381 - val_accuracy: 0.9762 - val_loss: 0.0593
# Epoch 42/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9742 - loss: 0.0565 - val_accuracy: 0.9701 - val_loss: 0.0814
# Epoch 43/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9804 - loss: 0.0517 - val_accuracy: 0.9687 - val_loss: 0.0681
# Epoch 44/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9818 - loss: 0.0354 - val_accuracy: 0.9755 - val_loss: 0.0604
# Epoch 45/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9840 - loss: 0.0355 - val_accuracy: 0.9694 - val_loss: 0.0720
# Epoch 46/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9834 - loss: 0.0380 - val_accuracy: 0.9680 - val_loss: 0.0798
# Epoch 47/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9837 - loss: 0.0343 - val_accuracy: 0.9789 - val_loss: 0.0607
# Epoch 48/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9857 - loss: 0.0328 - val_accuracy: 0.9762 - val_loss: 0.0703
# Epoch 49/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9891 - loss: 0.0301 - val_accuracy: 0.9803 - val_loss: 0.0626
# Epoch 50/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9875 - loss: 0.0280 - val_accuracy: 0.9796 - val_loss: 0.0638

# %%
test_pred_proba = cnn_model.predict(testX)
test_pred = np.argmax(test_pred_proba, axis=-1)
test_true = testy.astype(int) - 1
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
from sklearn.metrics import accuracy_score, classification_report
print("CNN Test Acc:", accuracy_score(test_true, test_pred))
print(classification_report(test_true, test_pred))
# Out:
# CNN Test Acc: 0.9151679674244995
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94       496
#            1       0.92      0.91      0.91       471
#            2       0.86      0.97      0.91       420
#            3       0.91      0.77      0.83       491
#            4       0.84      0.93      0.88       532
#            5       0.99      1.00      1.00       537
#
#     accuracy                           0.92      2947
#    macro avg       0.92      0.91      0.91      2947
# weighted avg       0.92      0.92      0.91      2947
